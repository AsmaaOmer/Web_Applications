# %% [markdown]
# This Kernel for someone want to deep dive into image classification. I use CNN for classification model. If you found this Kernel helpful please up vote it. If you have some feedback and question don't forget to comment below.
#
# I have simplier model with
# * https://www.kaggle.com/uysimty/get-start-image-classification

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("input"))


FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3
# Out:
# ['train', 'test1']

# %%
filenames = os.listdir("input/train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

#df.head()

# %%
# See sample image
sample = random.choice(filenames)
image = load_img("input/train/"+sample)
plt.imshow(image)

# %%
model.load_weights("model.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4cff5c951216> in <module>()
#       1
# ----> 2 model.load_weights("model.h5")
#
# /home/jumpco/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch)
#     248         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     249                          'with steps_per_run greater than 1.')
# --> 250     return super(Model, self).load_weights(filepath, by_name, skip_mismatch)
#     251
#     252   def compile(self,
#
# /home/jumpco/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/network.py in load_weights(self, filepath, by_name, skip_mismatch)
#    1256           'Model which has not created its variables yet. Call the Model '
#    1257           'first, then load the weights.')
# -> 1258     self._assert_weights_created()
#    1259     with h5py.File(filepath, 'r') as f:
#    1260       if 'layer_names' not in f.attrs and 'model_weights' in f:
#
# /home/jumpco/.local/lib/python3.7/site-packages/tensorflow/python/keras/engine/network.py in _assert_weights_created(self)
#    1560                        'Weights are created when the Model is first called on '
#    1561                        'inputs or `build()` is called with an `input_shape`.' %
# -> 1562                        self.name)
#    1563
#    1564   def _graph_network_add_loss(self, symbolic_loss):
#
# ValueError: Weights for model sequential have not yet been created. Weights are created when the Model is first called on inputs or `build()` is called with an `input_shape`.

# %%
import PIL.Image

from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

test_img = load_img("./input/train/cat.8.jpg")


test_img = test_img.resize((128,128) , resample=PIL.Image.BICUBIC)

test_arr = img_to_array(test_img)
test_arr = np.expand_dims(test_arr,axis = 0)
test_arr /= 255.0

plt.imshow(test_img)
score = model.predict(test_arr)

    
print("It's a dog!" if score[0][0] < 0.5 else"It's a cat!", score[0][1] if score[0][0] < 0.5 else  float(score[0][0]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-47b9ed47f06c> in <module>()
#       3 from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
#       4
# ----> 5 test_img = load_img("./input/train/cat.8.jpg")
#       6
#       7
#
# /home/jumpco/.local/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: './input/train/cat.8.jpg'
